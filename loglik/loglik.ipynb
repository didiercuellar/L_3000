# %%
import pandas as pd 
import numpy as np 
import scipy.stats as st 
from scipy.interpolate import interp1d
from matplotlib import pyplot as plt 
import math
import statistics as stats

# %%
data=pd.read_csv('loglik_U.csv',header=0,)
data = data.dropna(how='any')#quita los valores nan del documento
y=data.iloc[:,0]
w=data.iloc[:,1]
x=data.iloc[:,2]

print(stats.stdev(x))
print(data)
# Out:
# 1.4858944399056223e+45
#              A         B             C
# 0   106.092218  1.789340  2.860000e+45
# 1   114.110142  1.738364  4.120000e+44
# 2    67.115742  1.652795  3.030000e+44
# 3    71.672233  1.583762  7.530000e+44
# 4    90.909547  1.739032  7.450000e+44
# ..         ...       ...           ...
# 65   26.888604  1.523854  3.720000e+44
# 66   50.685901  1.648907  2.540000e+44
# 67   74.501411  1.637217  2.670000e+44
# 68   57.022922  1.636313  6.330000e+44
# 69   54.798717  1.597804  4.600000e+44
#
# [70 rows x 3 columns]

# %%
yerror = w
xerror = 1.4858944399056223e+45
plt.plot(x,y,'ro')
plt.errorbar(x,y,yerr=yerror, fmt = ' ' , ecolor='black')
plt.errorbar(x,y,xerr=xerror, fmt = ' ' , ecolor='blue')
plt.ylabel('loglik_U')
plt.xlabel('erg/s')
plt.title("L_3000_U")
plt.xscale('log')
#plt.yscale('log')
plt.grid()
plt.savefig("L_3000_loglik_U_error.pdf")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data=pd.read_csv('loglik_G.csv',header=0,)
data = data.dropna(how='any')#quita los valores nan del documento
y=data.iloc[:,0]
w=data.iloc[:,1]
x=data.iloc[:,2]

print(stats.stdev(x))
print(data)
# Out:
# 1.4858944399056223e+45
#              A         B             C
# 0   130.202316  1.949627  2.860000e+45
# 1   149.906770  2.918206  4.120000e+44
# 2   105.104500  1.736560  3.030000e+44
# 3    98.717990  1.618173  7.530000e+44
# 4   125.089477  2.485903  7.450000e+44
# ..         ...       ...           ...
# 65  101.750239  2.065254  3.720000e+44
# 66  100.952530  1.662809  2.540000e+44
# 67   91.296226  1.902346  2.670000e+44
# 68  118.548071  1.635332  6.330000e+44
# 69  100.190162  1.673830  4.600000e+44
#
# [70 rows x 3 columns]

# %%
yerror = w
xerror = 1.4858944399056223e+45
plt.plot(x,y,'ro')
plt.errorbar(x,y,yerr=yerror, fmt = ' ' , ecolor='black')
plt.errorbar(x,y,xerr=xerror, fmt = ' ' , ecolor='blue')
plt.ylabel('loglik_G')
plt.xlabel('erg/s')
plt.title("L_3000_G")
plt.xscale('log')
#plt.yscale('log')
plt.grid()
plt.savefig("L_3000_loglik_G_error.pdf")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data=pd.read_csv('loglik_R.csv',header=0,)
data = data.dropna(how='any')#quita los valores nan del documento
y=data.iloc[:,0]
w=data.iloc[:,1]
x=data.iloc[:,2]

print(stats.stdev(x))
print(data)
# Out:
# 1.4858944399056223e+45
#              A           B             C
# 0   154.399355    1.829780  2.860000e+45
# 1   150.212161    2.298551  4.120000e+44
# 2   109.168604    1.641570  3.030000e+44
# 3   117.038446    1.661915  7.530000e+44
# 4   131.885924    1.702738  7.450000e+44
# ..         ...         ...           ...
# 65  151.831032    1.706792  3.720000e+44
# 66  279.736000    1.961322  2.540000e+44
# 67  120.083331    1.709789  2.670000e+44
# 68  114.219733  114.219733  6.330000e+44
# 69  118.094155    1.616840  4.600000e+44
#
# [70 rows x 3 columns]

# %%
yerror = w
xerror = 1.4858944399056223e+45
plt.plot(x,y,'ro')
plt.errorbar(x,y,yerr=yerror, fmt = ' ' , ecolor='black')
plt.errorbar(x,y,xerr=xerror, fmt = ' ' , ecolor='blue')
plt.ylabel('loglik_R')
plt.xlabel('erg/s')
plt.title("L_3000_R")
plt.xscale('log')
#plt.yscale('log')
plt.grid()
plt.savefig("L_3000_loglik_R_error.pdf")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data=pd.read_csv('loglik_I.csv',header=0,)
data = data.dropna(how='any')#quita los valores nan del documento
y=data.iloc[:,0]
w=data.iloc[:,1]
x=data.iloc[:,2]

print(stats.stdev(x))
print(data)
# Out:
# 1.4858944399056223e+45
#              A         B             C
# 0   141.824069  3.040497  2.860000e+45
# 1   151.780281  2.574591  4.120000e+44
# 2    92.614660  1.641891  3.030000e+44
# 3   110.824485  2.394953  7.530000e+44
# 4   112.537535  2.833369  7.450000e+44
# ..         ...       ...           ...
# 65  139.909863  1.884320  3.720000e+44
# 66  258.353910  1.715715  2.540000e+44
# 67  106.595741  2.168879  2.670000e+44
# 68   96.048597  2.433608  6.330000e+44
# 69  119.202723  1.813164  4.600000e+44
#
# [70 rows x 3 columns]

# %%
yerror = w
xerror = 1.4858944399056223e+45
plt.plot(x,y,'ro')
plt.errorbar(x,y,yerr=yerror, fmt = ' ' , ecolor='black')
plt.errorbar(x,y,xerr=xerror, fmt = ' ' , ecolor='blue')
plt.ylabel('loglik_I')
plt.xlabel('erg/s')
plt.title("L_3000_I")
plt.xscale('log')
#plt.yscale('log')
plt.grid()
plt.savefig("L_3000_loglik_I_error.pdf")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
data=pd.read_csv('loglik_Z.csv',header=0,)
data = data.dropna(how='any')#quita los valores nan del documento
y=data.iloc[:,0]
w=data.iloc[:,1]
x=data.iloc[:,2]

print(stats.stdev(x))
print(data)
# Out:
# 1.4858944399056223e+45
#              A         B             C
# 0   137.892281  1.687340  2.860000e+45
# 1   113.125078  1.561252  4.120000e+44
# 2    54.439427  1.585758  3.030000e+44
# 3    65.567099  1.576602  7.530000e+44
# 4   100.513633  1.802875  7.450000e+44
# ..         ...       ...           ...
# 65   89.774687  1.570829  3.720000e+44
# 66   56.856055  1.613308  2.540000e+44
# 67   67.978592  2.351482  2.670000e+44
# 68   57.470200  1.640586  6.330000e+44
# 69   63.996105  1.570317  4.600000e+44
#
# [70 rows x 3 columns]

# %%
yerror = w
xerror = 1.4858944399056223e+45
plt.plot(x,y,'ro')
plt.errorbar(x,y,yerr=yerror, fmt = ' ' , ecolor='black')
plt.errorbar(x,y,xerr=xerror, fmt = ' ' , ecolor='blue')
plt.ylabel('loglik_Z')
plt.xlabel('erg/s')
plt.title("L_3000_Z")
plt.xscale('log')
#plt.yscale('log')
plt.grid()
plt.savefig("L_3000_loglik_Z_error.pdf")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
